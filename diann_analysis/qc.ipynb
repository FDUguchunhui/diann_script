# %%
import pandas as pd
import os
import re

# %%
citrullination = pd.read_csv('/rsrch5/scratch/ccp/hanash/Hanash_GPFS/Chunhui/DIANN_Testing/merged/RAINBOW_UNIPROT_human_revi_2024_12_19_ProteinAG_citrullination_report-lib.csv')

# %%
citrullination
# Out:
#                                                  File.Name  \
# 0        /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# 1        /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# 2        /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# 3        /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# 4        /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# ...                                                    ...
# 3365465  /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# 3365466  /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# 3365467  /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# 3365468  /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
# 3365469  /mnt/DIANN_Testing/data/RAINBOW/IPAS8000_PL377...
#
#                                               Run           Protein.Group  \
# 0        IPAS8000_PL377_IgB_MCED_163_S2-A1_1_1159                  P02766
# 1        IPAS8000_PL377_IgB_MCED_163_S2-A1_1_1159                  P02768
# ...

# %%
meta_data = pd.read_excel('/rsrch5/scratch/ccp/hanash/Hanash_GPFS/Chunhui/diann_analysis/data/EI_key_rainbow.xlsx')
meta_data
# Out:
#                                            PLateNumber       MCED Consider  \
# 0    [376] IPAS8000_PL380_FT_2437_S2-E8_1_1506.htrm...       2437      NaN
# 1    [80] IPAS8000_PL376_FT_HQC_1_S2-A10_1_454.htrm...      HQC_1      NaN
# 2    [377] IPAS8000_PL380_FT_HQC_1_S2-F8_1_1516.htr...      HQC_1      NaN
# 3    [81] IPAS8000_PL376_FT_HQC_2_S2-B10_1_464.htrm...      HQC_2      NaN
# 4    [228] IPAS8001_PL378_FT_HQC1_S4-A10_1_999.htrm...       HQC1      NaN
# ..                                                 ...        ...      ...
# 433  [226] IPAS8000_PL377_FT_MCED_HQC1_S2-A10_1_897...  MCED_HQC1      NaN
# 434  [74] IPAS8000_PL375_FT_MCED_HQC2_S4-B10_1_365....  MCED_HQC2      NaN
# 435  [227] IPAS8000_PL377_FT_MCED_HQC2_S2-B10_1_909...  MCED_HQC2      NaN
# 436  [367] IPAS8000_PL379_FT_V073_S2-A10_1_1309.htr...       V073      NaN
# 437  [368] IPAS8000_PL379_FT_V074_S2-B10_1_1321.htr...       V074      NaN
#
# ...
